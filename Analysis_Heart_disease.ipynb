# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("merged_copy_14cols_new_data.csv")
data
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8360   62    1   1       NaN  139.0  0.0      1.0      NaN    NaN      NaN
# 8361   55    1   4     122.0  223.0  1.0      1.0    100.0    0.0      0.0
# 8362   58    1   4       NaN  385.0  1.0      2.0      NaN    NaN      NaN
# 8363   62    1   2     120.0  254.0  0.0      2.0     93.0    1.0      0.0
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data_temp=data.copy()

# %%
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8360   62    1   1       NaN  139.0  0.0      1.0      NaN    NaN      NaN
# 8361   55    1   4     122.0  223.0  1.0      1.0    100.0    0.0      0.0
# 8362   58    1   4       NaN  385.0  1.0      2.0      NaN    NaN      NaN
# 8363   62    1   2     120.0  254.0  0.0      2.0     93.0    1.0      0.0
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data_temp.dropna(inplace=True)

# %%
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8040   68    1   4     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 8041   57    1   4     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 8042   57    0   2     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 8192   56    1   4     120.0  100.0  0.0      0.0    120.0    1.0      1.5
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data_temp.plot();

# %%
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8040   68    1   4     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 8041   57    1   4     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 8042   57    0   2     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 8192   56    1   4     120.0  100.0  0.0      0.0    120.0    1.0      1.5
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
# fig,ax=plt.subplots()
data_temp.plot(kind="hist",
              x="slope",
              y="age");

# %%
data_temp.plot(kind="scatter",
              x="age",
              y="slope");

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1   53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2   70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 1    0.0  0.0   3.0       0
# 2    0.0  0.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0

# %%
data_temp["slope"]=data_temp["slope"].replace('0.0','NAN')
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8040   68    1   4     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 8041   57    1   4     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 8042   57    0   2     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 8192   56    1   4     120.0  100.0  0.0      0.0    120.0    1.0      1.5
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
# area.replace(0, np.nan, inplace=True)
data_temp["slope"].replace(0,np.nan,inplace=True)

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1   53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2   70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 1    NaN  0.0   3.0       0
# 2    NaN  0.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0

# %%
data_temp.dropna(inplace=True)

# %%
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5      58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7      55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8040   68    1   4     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 8041   57    1   4     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 8042   57    0   2     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 8192   56    1   4     120.0  100.0  0.0      0.0    120.0    1.0      1.5
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1      53    1   0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2      70    1   0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8360   62    1   1       NaN  139.0  0.0      1.0      NaN    NaN      NaN
# 8361   55    1   4     122.0  223.0  1.0      1.0    100.0    0.0      0.0
# 8362   58    1   4       NaN  385.0  1.0      2.0      NaN    NaN      NaN
# 8363   62    1   2     120.0  254.0  0.0      2.0     93.0    1.0      0.0
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5      58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7      55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8040   68    1   4     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 8041   57    1   4     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 8042   57    0   2     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 8192   56    1   4     120.0  100.0  0.0      0.0    120.0    1.0      1.5
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data_temp.dropna(inplace=True)

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5   58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7   55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0
# 5    1.0  0.0   2.0       1
# 7    1.0  1.0   3.0       0

# %%
data_temp["slope"].replace(0,np.nan,inplace=True)

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5   58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7   55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0
# 5    1.0  0.0   2.0       1
# 7    1.0  1.0   3.0       0

# %%
data_temp.fillna(data_temp["slope"].median(),inplace=True)

# %%
data_temp
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3      61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4      62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5      58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7      55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 8040   68    1   4     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 8041   57    1   4     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 8042   57    0   2     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 8192   56    1   4     120.0  100.0  0.0      0.0    120.0    1.0      1.5
# 8364   47    1   4     150.0  226.0  0.0      0.0     98.0    1.0      1.5
#
#       slope   ca  thal  target
# 0       2.0  2.0   3.0       0
# ...

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5   58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7   55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0
# 5    1.0  0.0   2.0       1
# 7    1.0  1.0   3.0       0

# %%
data_temp.plot(kind="scatter",
              x='chol',
              y='thalach');

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5   58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7   55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0
# 5    1.0  0.0   2.0       1
# 7    1.0  1.0   3.0       0

# %%
data_temp.plot(kind="scatter",
              x='chol',
              y='ca',
              c='target',
              cmap='summer')
# Out:
# <AxesSubplot:xlabel='chol', ylabel='ca'>

# %%
data_temp.plot.scatter(x='age',
                      y='thalach',
                      cmap='summer',
                      c='target');

# %%
data_temp.plot.scatter(x='age',
                      y='chol',
                      c='target',
                      cmap='summer');

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5   58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7   55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0
# 5    1.0  0.0   2.0       1
# 7    1.0  1.0   3.0       0

# %%
data_temp.plot.scatter(x='age',
                      y='trestbps',
                      cmap='summer',
                      c='target');

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5   58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7   55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0
# 5    1.0  0.0   2.0       1
# 7    1.0  1.0   3.0       0

# %%
data_temp.plot.scatter(x='age',
                      y='chol',
                      c='restecg',
                      cmap='winter');

# %%
data_temp.plot.scatter(x='age',
                      y='thalach',
                      cmap='summer',
                      c='ca');

# %%
data_temp.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 3   61    1   0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4   62    0   0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# 5   58    0   0     100.0  248.0  0.0      0.0    122.0    0.0      1.0
# 7   55    1   0     160.0  289.0  0.0      0.0    145.0    1.0      0.8
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0       0
# 3    2.0  1.0   3.0       0
# 4    1.0  3.0   2.0       0
# 5    1.0  0.0   2.0       1
# 7    1.0  1.0   3.0       0

# %% [markdown]
# # age vs chol

# %%
data_temp.plot(kind="scatter",
              x="age",
              y='chol',
              c='target',
              cmap='summer');

# %% [markdown]
# # scatter plot with oldpeak vs chol

# %%
data_temp.plot(kind="scatter",
              x="oldpeak",
              y='chol',
              c='target',
              cmap='summer');

# %%
data_temp["oldpeak"]
# Out:
# 0       1.0
# 3       0.0
# 4       1.9
# 5       1.0
# 7       0.8
#        ...
# 8040    3.4
# 8041    1.2
# 8042    0.0
# 8192    1.5
# 8364    1.5
# Name: oldpeak, Length: 6876, dtype: float64

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# # plot for Target valve

# %%
data_temp.target.value_counts().plot(kind='bar',color=["salmon","lightblue"]);
# balanced valves are present
